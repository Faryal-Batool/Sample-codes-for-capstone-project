# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('/content/drive/MyDrive/All drones.csv')

# training gaussian mixture model
from sklearn.mixture import GaussianMixture
gmm = GaussianMixture(n_components=5)
gmm.fit(data)

#predictions from gmm
labels = gmm.predict(data)
frame = pd.DataFrame(data)
frame['cluster'] = labels
frame.columns = ['PC1', 'PC2','PC3','PC4','PC5','PC6','PC7','PC8','PC9','PC10','PC11','PC12','PC13','PC14','PC15', 'cluster',]

color=['blue','green','cyan', 'black','red']
for k in range(0,5):
    data = frame[frame["cluster"]==k]
    plt.scatter(data["PC1"],data["PC2"],c=color[k])
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
X = pd.read_csv('/content/drive/MyDrive/All drones.csv')
n_components = np.arange(2, 11)
models = [GaussianMixture(n, covariance_type='full', random_state=0).fit(X)
          for n in n_components]

plt.plot(n_components, [m.bic(X) for m in models], label='BIC')
plt.plot(n_components, [m.aic(X) for m in models], label='AIC')
plt.legend(loc='best')
plt.xlabel('n_components');

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('/content/drive/MyDrive/35_contamination.csv')

# training gaussian mixture model
from sklearn.mixture import GaussianMixture
gmm = GaussianMixture(n_components=5)
gmm.fit(data)

#predictions from gmm
labels = gmm.predict(data)
frame = pd.DataFrame(data)
frame['cluster'] = labels
frame.columns = ['PC1', 'PC2','PC3','PC4','PC5','PC6','PC7','PC8','PC9','PC10','PC11','PC12','PC13','PC14','PC15', 'cluster',]

color=['blue','green','cyan', 'black','red']
for k in range(0,5):
    data = frame[frame["cluster"]==k]
    plt.scatter(data["PC1"],data["PC2"],c=color[k])
plt.show()
